# %%
import subprocess

# inner, outer, naive-row-wise
def run_experiment(dataflow, density):
    print("- starting experiment...")
    density=str(density)
    cmd="timeloop-mapper arch/sparse-exporation-architecture.yaml arch/components/*.yaml prob/prob" + density + ".yaml mapper/mapper.yaml constraints/" + dataflow + "-product-arch-constraints.yaml sparse-opt/" + dataflow + "-product.yaml  -o output/"
    subprocess.run(["timeloop-mapper","arch/sparse-exporation-architecture.yaml","arch/components/*.yaml","prob/prob" + density + ".yaml","mapper/mapper.yaml","constraints/" + dataflow + "-product-arch-constraints.yaml","sparse-opt/" + dataflow + "-product.yaml","-o","output/"],capture_output=True,text=True,bufsize=1)
    print("- done with experiment")

# %%
# Parse edp, energy, cycles, and area from log file
def parse_edp(pth):
    f=open(pth)
    log_txt=f.read()
    f.close()
    energy=float([s for s in log_txt.split("\n") if "Total topology energy" in s][0].split()[3])
    cycles=float([s for s in log_txt.split("\n") if "Max topology cycles" in s][0].split()[3])
    area=float([s for s in log_txt.split("\n") if "Total topology area" in s][0].split()[3])
    return {"edp":energy*cycles,"energy":energy,"cycles":cycles,"area":area}

# %%
from parse_timeloop_output import parse_timeloop_stats
import pickle

def dictappend(dct, key, value):
    if key in dct:
        dct[key] = dct[key] + [value]
    else:
        dct[key] = [value]
        
    return dct

#density = [1.0, 0.1, 0.01, 0.001, 0.0001, 0.00001]
density = [1.0, 0.01,  0.0001]
density_str = [str(d) for d in density]
# experiment_str = ["inner", "outer", "naive-row-wise"]
experiment_str = ["inner", "outer", "naive-row-wise"]
result = {}
detailed_result = {}
mapper_result = {}

for ddx in range(len(density)):
    print("Density: " + density_str[ddx])
    for ex in experiment_str:
        print("- Experiment: " + ex + " product")
        run_experiment(ex, density_str[ddx])
        stats = parse_timeloop_stats('./output/timeloop-mapper.map+stats.xml')
        mapper = []
        with open("./output/timeloop-mapper.map.txt") as file:
            mapper = file.read()
        mapper_result = dictappend(mapper_result, ex, mapper)
        stats['edp_pJ_cycles'] = stats['energy_pJ']*stats['cycles']
        result = dictappend(result, ex, stats['edp_pJ_cycles'])
        detailed_result = dictappend(detailed_result, ex, stats)
        print("-- EDP: " + str(result[ex][ddx]) + " pJ-cycles")
        print("-- Mapping:")
        print(mapper)
        print("")
        print("")

pickle.dump( {"result":result,"detailed_result":result,"mapper_results""density":density, "experiment_str":experiment_str}, open( "./output/experiment_result.p", "wb" ) )
# Out:
# Density: 1.0
# - Experiment: inner product
# - starting experiment...
# - done with experiment
# -- EDP: 4309552610860629.0 pJ-cycles
# -- Mapping:
#
# BackingStorage [ A:262144 (262144) B:262144 (262144) Z:262144 (262144) ]
# ------------------------------------------------------------------------
# | for M in [0:32)
# |   for M in [0:16) (Spatial-X)
# |     for N in [0:16) (Spatial-X)
#
# Buffer [ Z:32 (32) ]
# --------------------
# |       for K in [0:512)
# |         for N in [0:32)
#
#
#
#
# - Experiment: outer product
# - starting experiment...
# - done with experiment
# -- EDP: 1371152028787246.5 pJ-cycles
# -- Mapping:
#
# BackingStorage [ A:262144 (262144) B:262144 (262144) Z:262144 (262144) ]
# ------------------------------------------------------------------------
# | for K in [0:2)
# |   for M in [0:16)
# |     for N in [0:512)
# |       for K in [0:256) (Spatial-X)
#
# Buffer [ A:32 (32) B:1 (1) ]
# ----------------------------
# |         for M in [0:32)
#
#
#
#
# - Experiment: naive-row-wise product
# - starting experiment...
# - done with experiment
# -- EDP: 1371431174702178.0 pJ-cycles
# -- Mapping:
#
# BackingStorage [ A:262144 (262144) B:262144 (262144) Z:262144 (262144) ]
# ------------------------------------------------------------------------
# | for M in [0:16)
# |   for K in [0:2)
# |     for N in [0:512)
# |       for K in [0:256) (Spatial-X)
#
# Buffer [ A:32 (32) B:1 (1) ]
# ----------------------------
# |         for M in [0:32)
#
#
#
#
# Density: 0.01
# - Experiment: inner product
# - starting experiment...
# - done with experiment
# -- EDP: 30609166035532.203 pJ-cycles
# -- Mapping:
#
# BackingStorage [ A:262144 (2622) B:262144 (2622) Z:262144 (27) ]
# ----------------------------------------------------------------
# | for M in [0:2)
# |   for M in [0:256) (Spatial-X)
#
# Buffer [ A:512 (6) Z:512 (1) ]
# ------------------------------
# |     for K in [0:512)
# |       for N in [0:512)
#
#
#
#
# - Experiment: outer product
# - starting experiment...
# - done with experiment
# -- EDP: 30609166035532.203 pJ-cycles
# -- Mapping:
#
# BackingStorage [ A:262144 (2622) B:262144 (2622) Z:262144 (27) ]
# ----------------------------------------------------------------
# | for M in [0:2)
# |   for M in [0:256) (Spatial-X)
#
# Buffer [ A:512 (6) Z:512 (1) ]
# ------------------------------
# |     for K in [0:512)
# |       for N in [0:512)
#
#
#
#
# - Experiment: naive-row-wise product
# - starting experiment...
# - done with experiment
# -- EDP: 30609166035532.203 pJ-cycles
# -- Mapping:
#
# BackingStorage [ A:262144 (2622) B:262144 (2622) Z:262144 (27) ]
# ----------------------------------------------------------------
# | for M in [0:2)
# |   for M in [0:256) (Spatial-X)
#
# Buffer [ A:512 (6) Z:512 (1) ]
# ------------------------------
# |     for K in [0:512)
# |       for N in [0:512)
#
#
#
#
# Density: 0.0001
# - Experiment: inner product
# - starting experiment...
# - done with experiment
# -- EDP: 12903069853987.91 pJ-cycles
# -- Mapping:
#
# BackingStorage [ A:262144 (27) B:262144 (27) Z:262144 (1) ]
# -----------------------------------------------------------
# | for M in [0:2)
# |   for M in [0:256) (Spatial-X)
#
# Buffer [ A:512 (1) Z:512 (1) ]
# ------------------------------
# |     for K in [0:512)
# |       for N in [0:512)
#
#
#
#
# - Experiment: outer product
# - starting experiment...
# - done with experiment
# -- EDP: 12903069853987.91 pJ-cycles
# -- Mapping:
#
# BackingStorage [ A:262144 (27) B:262144 (27) Z:262144 (1) ]
# -----------------------------------------------------------
# | for M in [0:2)
# |   for M in [0:256) (Spatial-X)
#
# Buffer [ A:512 (1) Z:512 (1) ]
# ------------------------------
# |     for K in [0:512)
# |       for N in [0:512)
#
#
#
#
# - Experiment: naive-row-wise product
# - starting experiment...
# - done with experiment
# -- EDP: 12903069853987.91 pJ-cycles
# -- Mapping:
#
# BackingStorage [ A:262144 (27) B:262144 (27) Z:262144 (1) ]
# -----------------------------------------------------------
# | for M in [0:2)
# |   for M in [0:256) (Spatial-X)
#
# Buffer [ A:512 (1) Z:512 (1) ]
# ------------------------------
# |     for K in [0:512)
# |       for N in [0:512)

# %%
density
# Out:
# [1.0]

# %%
print(result)
# Out:
# {'inner': [1045175127234482.1]}

# %%
# importing package
import matplotlib.pyplot as plt
import numpy as np

marker_str = ["x","o","*"]

# plot lines
for ex in range(len(experiment_str)):
    ex_str = experiment_str[ex]
    plt.plot(density, [el for el in result[ex_str]], label = ex_str + "-product",marker=marker_str[ex],linestyle='--')
plt.grid(True)
plt.xscale('log')
plt.yscale('log')
plt.title("Comparison of loop-nest orderings based on EDP\n(Dataflow re-optimized at each density)")
plt.xlabel("Density")
plt.ylabel("EDP")
plt.legend()
plt.show()

# %%
# Parse SparseLoop XML output
import xml.etree.ElementTree as ET

# create element tree object
tree = ET.parse("timeloop-model.map+stats.xml")

# get root element
root = tree.getroot()

root.tag

root.attrib

for child in root:
    print(child.tag, child.attrib)
    
ET.dump(tree)
# Out:
# engine {'class_id': '0', 'tracking_level': '0', 'version': '0'}
# mapping {'class_id': '30', 'tracking_level': '0', 'version': '0'}
# a {'class_id': '32', 'tracking_level': '1', 'version': '0', 'object_id': '_7'}
# <boost_serialization signature="serialization::archive" version="15">
# <engine class_id="0" tracking_level="0" version="0">
# 	<topology_ class_id="1" tracking_level="0" version="0">
# 		<levels_ class_id="2" tracking_level="0" version="0">
# 			<count>4</count>
# 			<item_version>1</item_version>
# 			<item class_id="3" tracking_level="0" version="1">
# 				<px class_id="4" class_name="model::ArithmeticUnits" tracking_level="1" version="0" object_id="_0">
# 					<Level class_id="5" tracking_level="0" version="0" />
# 					<specs_ class_id="6" tracking_level="0" version="0">
# 						<LevelSpecs class_id="7" tracking_level="0" version="0">
# 							<level_name>mac</level_name>
# 						</LevelSpecs>
# 						<instances class_id="8" tracking_level="0" version="0">
# 							<t_>8</t_>
# 						</instances>
# 						<meshX>
# 							<t_>8</t_>
# 						</meshX>
# 						<meshY>
# 							<t_>1</t_>
# 						</meshY>
# 						<word_bits>
# 							<t_>16</t_>
# 						</word_bits>
# 					</specs_>
# 					<energy_>1.12657919999999990e+03</energy_>
# 					<area_>1.23950000000000000e+03</area_>
# 					<cycles_>64</cycles_>
# 					<utilized_instances_>8</utilized_instances_>
# 					<algorithmic_computes_>512</algorithmic_computes_>
# 					<random_computes_>512</random_computes_>
# 					<gated_computes_>0</gated_computes_>
# 					<skipped_computes_>0</skipped_computes_>
# 				</px>
# 			</item>
# 			<item>
# 				<px class_id="9" class_name="model::BufferLevel" tracking_level="1" version="0" object_id="_1">
# 					<Level />
# 					<subnest_ class_id="10" tracking_level="0" version="0">
# 						<count>1</count>
# 						<item_version>0</item_version>
# 						<item class_id="11" tracking_level="0" version="0">
# 							<dimension>2</dimension>
# 							<start>0</start>
# 							<end>8</end>
# 							<stride>1</stride>
# 							<spacetime_dimension>0</spacetime_dimension>
# 						</item>
# 					</subnest_>
# 					<specs_ class_id="12" tracking_level="0" version="0">
# 						<LevelSpecs>
# 							<level_name>spAL</level_name>
# 						</LevelSpecs>
# 						<name class_id="13" tracking_level="0" version="0">
# 							<t_>spAL</t_>
# 						</name>
# 						<technology class_id="14" tracking_level="0" version="0">
# 							<t_>0</t_>
# 						</technology>
# 						<size>
# 							<t_>1</t_>
# 						</size>
# 						<word_bits>
# 							<t_>16</t_>
# 						</word_bits>
# 						<addr_gen_bits>
# 							<t_>0</t_>
# 						</addr_gen_bits>
# 						<block_size>
# 							<t_>1</t_>
# 						</block_size>
# 						<cluster_size>
# 							<t_>1</t_>
# 						</cluster_size>
# 						<instances>
# 							<t_>8</t_>
# 						</instances>
# 						<meshX>
# 							<t_>8</t_>
# 						</meshX>
# 						<meshY>
# 							<t_>1</t_>
# 						</meshY>
# 						<read_bandwidth class_id="15" tracking_level="0" version="0">
# 							<t_>1.60000000000000000e+01</t_>
# 						</read_bandwidth>
# 						<write_bandwidth>
# 							<t_>1.60000000000000000e+01</t_>
# 						</write_bandwidth>
# 						<multiple_buffering>
# 							<t_>1.00000000000000000e+00</t_>
# 						</multiple_buffering>
# 						<min_utilization>
# 							<t_>0.00000000000000000e+00</t_>
# 						</min_utilization>
# 						<num_ports>
# 							<t_>2</t_>
# 						</num_ports>
# 						<num_banks>
# 							<t_>1</t_>
# 						</num_banks>
# 						<read_network_name />
# 						<fill_network_name />
# 						<drain_network_name />
# 						<update_network_name />
# 					</specs_>
# 					<stats_ class_id="16" tracking_level="0" version="0">
# 						<keep class_id="17" tracking_level="0" version="0">
# 							<PerDataSpace>
# 								<item>1</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</keep>
# 						<partition_size class_id="18" tracking_level="0" version="0">
# 							<PerDataSpace>
# 								<item>8</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</partition_size>
# 						<utilized_capacity>
# 							<PerDataSpace>
# 								<item>1</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</utilized_capacity>
# 						<utilized_instances>
# 							<PerDataSpace>
# 								<item>8</item>
# 								<item>8</item>
# 								<item>8</item>
# 							</PerDataSpace>
# 						</utilized_instances>
# 						<utilized_clusters>
# 							<PerDataSpace>
# 								<item>8</item>
# 								<item>8</item>
# 								<item>8</item>
# 							</PerDataSpace>
# 						</utilized_clusters>
# 						<reads>
# 							<PerDataSpace>
# 								<item>64</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</reads>
# 						<updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</updates>
# 						<fills>
# 							<PerDataSpace>
# 								<item>8</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</fills>
# 						<metadata_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</metadata_reads>
# 						<metadata_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</metadata_fills>
# 						<metadata_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</metadata_updates>
# 						<gated_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_reads>
# 						<skipped_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_reads>
# 						<random_reads>
# 							<PerDataSpace>
# 								<item>64</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</random_reads>
# 						<gated_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_fills>
# 						<skipped_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_fills>
# 						<random_fills>
# 							<PerDataSpace>
# 								<item>8</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</random_fills>
# 						<gated_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_updates>
# 						<skipped_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_updates>
# 						<random_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</random_updates>
# 						<random_metadata_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</random_metadata_reads>
# 						<gated_metadata_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_metadata_reads>
# 						<skipped_metadata_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_metadata_reads>
# 						<random_metadata_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</random_metadata_fills>
# 						<gated_metadata_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_metadata_fills>
# 						<skipped_metadata_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_metadata_fills>
# 						<random_metadata_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</random_metadata_updates>
# 						<gated_metadata_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_metadata_updates>
# 						<skipped_metadata_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_metadata_updates>
# 						<decompression_counts>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</decompression_counts>
# 						<compression_counts>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</compression_counts>
# 						<address_generations>
# 							<PerDataSpace>
# 								<item>72</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</address_generations>
# 						<temporal_reductions>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</temporal_reductions>
# 						<read_bandwidth class_id="19" tracking_level="0" version="0">
# 							<PerDataSpace>
# 								<item>1.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 							</PerDataSpace>
# 						</read_bandwidth>
# 						<write_bandwidth>
# 							<PerDataSpace>
# 								<item>1.25000000000000000e-01</item>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 							</PerDataSpace>
# 						</write_bandwidth>
# 						<energy_per_algorithmic_access>
# 							<PerDataSpace>
# 								<item>1.92799999999999999e-01</item>
# 								<item>-nan</item>
# 								<item>-nan</item>
# 							</PerDataSpace>
# 						</energy_per_algorithmic_access>
# 						<energy_per_access>
# 							<PerDataSpace>
# 								<item>1.92799999999999999e-01</item>
# 								<item>-nan</item>
# 								<item>-nan</item>
# 							</PerDataSpace>
# 						</energy_per_access>
# 						<energy>
# 							<PerDataSpace>
# 								<item>1.38816000000000006e+01</item>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 							</PerDataSpace>
# 						</energy>
# 						<temporal_reduction_energy>
# 							<PerDataSpace>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 							</PerDataSpace>
# 						</temporal_reduction_energy>
# 						<addr_gen_energy>
# 							<PerDataSpace>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 							</PerDataSpace>
# 						</addr_gen_energy>
# 						<cycles>64</cycles>
# 						<slowdown>1.00000000000000000e+00</slowdown>
# 					</stats_>
# 				</px>
# 			</item>
# 			<item>
# 				<px class_id_reference="9" object_id="_2">
# 					<Level />
# 					<subnest_>
# 						<count>1</count>
# 						<item_version>0</item_version>
# 						<item>
# 							<dimension>1</dimension>
# 							<start>0</start>
# 							<end>8</end>
# 							<stride>1</stride>
# 							<spacetime_dimension>0</spacetime_dimension>
# 						</item>
# 					</subnest_>
# 					<specs_>
# 						<LevelSpecs>
# 							<level_name>merge_queue</level_name>
# 						</LevelSpecs>
# 						<name>
# 							<t_>merge_queue</t_>
# 						</name>
# 						<technology>
# 							<t_>0</t_>
# 						</technology>
# 						<size>
# 							<t_>1024</t_>
# 						</size>
# 						<word_bits>
# 							<t_>16</t_>
# 						</word_bits>
# 						<addr_gen_bits>
# 							<t_>10</t_>
# 						</addr_gen_bits>
# 						<block_size>
# 							<t_>1</t_>
# 						</block_size>
# 						<cluster_size>
# 							<t_>20</t_>
# 						</cluster_size>
# 						<instances>
# 							<t_>8</t_>
# 						</instances>
# 						<meshX>
# 							<t_>8</t_>
# 						</meshX>
# 						<meshY>
# 							<t_>1</t_>
# 						</meshY>
# 						<read_bandwidth>
# 							<t_>1.60000000000000000e+01</t_>
# 						</read_bandwidth>
# 						<write_bandwidth>
# 							<t_>1.60000000000000000e+01</t_>
# 						</write_bandwidth>
# 						<multiple_buffering>
# 							<t_>1.00000000000000000e+00</t_>
# 						</multiple_buffering>
# 						<min_utilization>
# 							<t_>0.00000000000000000e+00</t_>
# 						</min_utilization>
# 						<num_ports>
# 							<t_>2</t_>
# 						</num_ports>
# 						<num_banks>
# 							<t_>2</t_>
# 						</num_banks>
# 						<read_network_name />
# 						<fill_network_name />
# 						<drain_network_name />
# 						<update_network_name />
# 					</specs_>
# 					<stats_>
# 						<keep>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>1</item>
# 							</PerDataSpace>
# 						</keep>
# 						<partition_size>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>8</item>
# 							</PerDataSpace>
# 						</partition_size>
# 						<utilized_capacity>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>8</item>
# 							</PerDataSpace>
# 						</utilized_capacity>
# 						<utilized_instances>
# 							<PerDataSpace>
# 								<item>8</item>
# 								<item>8</item>
# 								<item>8</item>
# 							</PerDataSpace>
# 						</utilized_instances>
# 						<utilized_clusters>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</utilized_clusters>
# 						<reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>56</item>
# 							</PerDataSpace>
# 						</reads>
# 						<updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>64</item>
# 							</PerDataSpace>
# 						</updates>
# 						<fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>8</item>
# 							</PerDataSpace>
# 						</fills>
# 						<metadata_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</metadata_reads>
# 						<metadata_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</metadata_fills>
# 						<metadata_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</metadata_updates>
# 						<gated_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_reads>
# 						<skipped_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_reads>
# 						<random_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>56</item>
# 							</PerDataSpace>
# 						</random_reads>
# 						<gated_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_fills>
# 						<skipped_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_fills>
# 						<random_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>8</item>
# 							</PerDataSpace>
# 						</random_fills>
# 						<gated_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_updates>
# 						<skipped_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_updates>
# 						<random_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>64</item>
# 							</PerDataSpace>
# 						</random_updates>
# 						<random_metadata_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</random_metadata_reads>
# 						<gated_metadata_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_metadata_reads>
# 						<skipped_metadata_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_metadata_reads>
# 						<random_metadata_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</random_metadata_fills>
# 						<gated_metadata_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_metadata_fills>
# 						<skipped_metadata_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_metadata_fills>
# 						<random_metadata_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</random_metadata_updates>
# 						<gated_metadata_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_metadata_updates>
# 						<skipped_metadata_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_metadata_updates>
# 						<decompression_counts>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</decompression_counts>
# 						<compression_counts>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</compression_counts>
# 						<address_generations>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>72</item>
# 							</PerDataSpace>
# 						</address_generations>
# 						<temporal_reductions>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>56</item>
# 							</PerDataSpace>
# 						</temporal_reductions>
# 						<read_bandwidth>
# 							<PerDataSpace>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 								<item>8.75000000000000000e-01</item>
# 							</PerDataSpace>
# 						</read_bandwidth>
# 						<write_bandwidth>
# 							<PerDataSpace>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 								<item>1.12500000000000000e+00</item>
# 							</PerDataSpace>
# 						</write_bandwidth>
# 						<energy_per_algorithmic_access>
# 							<PerDataSpace>
# 								<item>-nan</item>
# 								<item>-nan</item>
# 								<item>0.00000000000000000e+00</item>
# 							</PerDataSpace>
# 						</energy_per_algorithmic_access>
# 						<energy_per_access>
# 							<PerDataSpace>
# 								<item>-nan</item>
# 								<item>-nan</item>
# 								<item>0.00000000000000000e+00</item>
# 							</PerDataSpace>
# 						</energy_per_access>
# 						<energy>
# 							<PerDataSpace>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 							</PerDataSpace>
# 						</energy>
# 						<temporal_reduction_energy>
# 							<PerDataSpace>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 							</PerDataSpace>
# 						</temporal_reduction_energy>
# 						<addr_gen_energy>
# 							<PerDataSpace>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 							</PerDataSpace>
# 						</addr_gen_energy>
# 						<cycles>64</cycles>
# 						<slowdown>1.00000000000000000e+00</slowdown>
# 					</stats_>
# 				</px>
# 			</item>
# 			<item>
# 				<px class_id_reference="9" object_id="_3">
# 					<Level />
# 					<subnest_>
# 						<count>2</count>
# 						<item_version>0</item_version>
# 						<item>
# 							<dimension>0</dimension>
# 							<start>0</start>
# 							<end>8</end>
# 							<stride>1</stride>
# 							<spacetime_dimension>1</spacetime_dimension>
# 						</item>
# 						<item>
# 							<dimension>2</dimension>
# 							<start>0</start>
# 							<end>1</end>
# 							<stride>1</stride>
# 							<spacetime_dimension>0</spacetime_dimension>
# 						</item>
# 					</subnest_>
# 					<specs_>
# 						<LevelSpecs>
# 							<level_name>DRAM</level_name>
# 						</LevelSpecs>
# 						<name>
# 							<t_>DRAM</t_>
# 						</name>
# 						<technology>
# 							<t_>1</t_>
# 						</technology>
# 						<size />
# 						<word_bits>
# 							<t_>16</t_>
# 						</word_bits>
# 						<addr_gen_bits>
# 							<t_>8</t_>
# 						</addr_gen_bits>
# 						<block_size>
# 							<t_>1</t_>
# 						</block_size>
# 						<cluster_size>
# 							<t_>1</t_>
# 						</cluster_size>
# 						<instances>
# 							<t_>1</t_>
# 						</instances>
# 						<meshX>
# 							<t_>1</t_>
# 						</meshX>
# 						<meshY>
# 							<t_>1</t_>
# 						</meshY>
# 						<read_bandwidth />
# 						<write_bandwidth />
# 						<multiple_buffering>
# 							<t_>1.00000000000000000e+00</t_>
# 						</multiple_buffering>
# 						<min_utilization>
# 							<t_>0.00000000000000000e+00</t_>
# 						</min_utilization>
# 						<num_ports>
# 							<t_>2</t_>
# 						</num_ports>
# 						<num_banks>
# 							<t_>2</t_>
# 						</num_banks>
# 						<read_network_name />
# 						<fill_network_name />
# 						<drain_network_name />
# 						<update_network_name />
# 					</specs_>
# 					<stats_>
# 						<keep>
# 							<PerDataSpace>
# 								<item>1</item>
# 								<item>1</item>
# 								<item>1</item>
# 							</PerDataSpace>
# 						</keep>
# 						<partition_size>
# 							<PerDataSpace>
# 								<item>64</item>
# 								<item>64</item>
# 								<item>64</item>
# 							</PerDataSpace>
# 						</partition_size>
# 						<utilized_capacity>
# 							<PerDataSpace>
# 								<item>64</item>
# 								<item>64</item>
# 								<item>64</item>
# 							</PerDataSpace>
# 						</utilized_capacity>
# 						<utilized_instances>
# 							<PerDataSpace>
# 								<item>1</item>
# 								<item>1</item>
# 								<item>1</item>
# 							</PerDataSpace>
# 						</utilized_instances>
# 						<utilized_clusters>
# 							<PerDataSpace>
# 								<item>1</item>
# 								<item>1</item>
# 								<item>1</item>
# 							</PerDataSpace>
# 						</utilized_clusters>
# 						<reads>
# 							<PerDataSpace>
# 								<item>64</item>
# 								<item>64</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</reads>
# 						<updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>64</item>
# 							</PerDataSpace>
# 						</updates>
# 						<fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</fills>
# 						<metadata_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</metadata_reads>
# 						<metadata_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</metadata_fills>
# 						<metadata_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</metadata_updates>
# 						<gated_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_reads>
# 						<skipped_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_reads>
# 						<random_reads>
# 							<PerDataSpace>
# 								<item>64</item>
# 								<item>64</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</random_reads>
# 						<gated_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_fills>
# 						<skipped_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_fills>
# 						<random_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</random_fills>
# 						<gated_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_updates>
# 						<skipped_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_updates>
# 						<random_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>64</item>
# 							</PerDataSpace>
# 						</random_updates>
# 						<random_metadata_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</random_metadata_reads>
# 						<gated_metadata_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_metadata_reads>
# 						<skipped_metadata_reads>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_metadata_reads>
# 						<random_metadata_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</random_metadata_fills>
# 						<gated_metadata_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_metadata_fills>
# 						<skipped_metadata_fills>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_metadata_fills>
# 						<random_metadata_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</random_metadata_updates>
# 						<gated_metadata_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</gated_metadata_updates>
# 						<skipped_metadata_updates>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</skipped_metadata_updates>
# 						<decompression_counts>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</decompression_counts>
# 						<compression_counts>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</compression_counts>
# 						<address_generations>
# 							<PerDataSpace>
# 								<item>64</item>
# 								<item>64</item>
# 								<item>64</item>
# 							</PerDataSpace>
# 						</address_generations>
# 						<temporal_reductions>
# 							<PerDataSpace>
# 								<item>0</item>
# 								<item>0</item>
# 								<item>0</item>
# 							</PerDataSpace>
# 						</temporal_reductions>
# 						<read_bandwidth>
# 							<PerDataSpace>
# 								<item>1.00000000000000000e+00</item>
# 								<item>1.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 							</PerDataSpace>
# 						</read_bandwidth>
# 						<write_bandwidth>
# 							<PerDataSpace>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 								<item>1.00000000000000000e+00</item>
# 							</PerDataSpace>
# 						</write_bandwidth>
# 						<energy_per_algorithmic_access>
# 							<PerDataSpace>
# 								<item>6.23999999999999986e+01</item>
# 								<item>6.23999999999999986e+01</item>
# 								<item>6.23999999999999986e+01</item>
# 							</PerDataSpace>
# 						</energy_per_algorithmic_access>
# 						<energy_per_access>
# 							<PerDataSpace>
# 								<item>6.23999999999999986e+01</item>
# 								<item>6.23999999999999986e+01</item>
# 								<item>6.23999999999999986e+01</item>
# 							</PerDataSpace>
# 						</energy_per_access>
# 						<energy>
# 							<PerDataSpace>
# 								<item>3.99359999999999991e+03</item>
# 								<item>3.99359999999999991e+03</item>
# 								<item>3.99359999999999991e+03</item>
# 							</PerDataSpace>
# 						</energy>
# 						<temporal_reduction_energy>
# 							<PerDataSpace>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 							</PerDataSpace>
# 						</temporal_reduction_energy>
# 						<addr_gen_energy>
# 							<PerDataSpace>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 								<item>0.00000000000000000e+00</item>
# 							</PerDataSpace>
# 						</addr_gen_energy>
# 						<cycles>64</cycles>
# 						<slowdown>1.00000000000000000e+00</slowdown>
# 					</stats_>
# 				</px>
# 			</item>
# 		</levels_>
# 		<networks_ class_id="20" tracking_level="0" version="0">
# 			<count>3</count>
# 			<item_version>0</item_version>
# 			<item class_id="21" tracking_level="0" version="0">
# 				<first>DRAM &lt;==&gt; merge_queue</first>
# 				<second class_id="22" tracking_level="0" version="1">
# 					<px class_id="23" class_name="model::LegacyNetwork" tracking_level="1" version="0" object_id="_4">
# 						<Network class_id="24" tracking_level="0" version="0" />
# 						<specs_ class_id="25" tracking_level="0" version="0">
# 							<NetworkSpecs class_id="26" tracking_level="0" version="0">
# 								<name>DRAM &lt;==&gt; merge_queue</name>
# 							</NetworkSpecs>
# 							<word_bits>
# 								<t_>16</t_>
# 							</word_bits>
# 							<router_energy />
# 							<wire_energy />
# 							<tile_width>
# 								<t_>1.24087187847852690e+02</t_>
# 							</tile_width>
# 							<energy_per_hop />
# 						</specs_>
# 						<stats_ class_id="27" tracking_level="0" version="0">
# 							<fanout>
# 								<PerDataSpace>
# 									<item>8</item>
# 									<item>8</item>
# 									<item>8</item>
# 								</PerDataSpace>
# 							</fanout>
# 							<distributed_fanout>
# 								<PerDataSpace>
# 									<item>0</item>
# 									<item>0</item>
# 									<item>0</item>
# 								</PerDataSpace>
# 							</distributed_fanout>
# 							<multicast_factor>
# 								<PerDataSpace>
# 									<item>1</item>
# 									<item>8</item>
# 									<item>1</item>
# 								</PerDataSpace>
# 							</multicast_factor>
# 							<ingresses class_id="28" tracking_level="0" version="0">
# 								<PerDataSpace>
# 									<item>
# 										<count>8</count>
# 										<item_version>0</item_version>
# 										<item>64</item>
# 										<item>0</item>
# 										<item>0</item>
# 										<item>0</item>
# 										<item>0</item>
# 										<item>0</item>
# 										<item>0</item>
# 										<item>0</item>
# 									</item>
# 									<item>
# 										<count>8</count>
# 										<item_version>0</item_version>
# 										<item>0</item>
# 										<item>0</item>
# 										<item>0</item>
# 										<item>0</item>
# 										<item>0</item>
# 										<item>0</item>
# 										<item>0</item>
# 										<item>64</item>
# 									</item>
# 									<item>
# 										<count>8</count>
# 										<item_version>0</item_version>
# 										<item>64</item>
# 										<item>0</item>
# 										<item>0</item>
# 										<item>0</item>
# 										<item>0</item>
# 										<item>0</item>
# 										<item>0</item>
# 										<item>0</item>
# 									</item>
# 								</PerDataSpace>
# 							</ingresses>
# 							<distributed_multicast>
# 								<PerDataSpace>
# 									<item>0</item>
# 									<item>0</item>
# 									<item>0</item>
# 								</PerDataSpace>
# 							</distributed_multicast>
# 							<link_transfers>
# 								<PerDataSpace>
# 									<item>0</item>
# 									<item>0</item>
# 									<item>0</item>
# 								</PerDataSpace>
# 							</link_transfers>
# 							<spatial_reductions>
# 								<PerDataSpace>
# 									<item>0</item>
# 									<item>0</item>
# 									<item>0</item>
# 								</PerDataSpace>
# 							</spatial_reductions>
# 							<link_transfer_energy>
# 								<PerDataSpace>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 								</PerDataSpace>
# 							</link_transfer_energy>
# 							<num_hops>
# 								<PerDataSpace>
# 									<item>1.41421356237309537e+00</item>
# 									<item>7.50000000000000178e+00</item>
# 									<item>1.41421356237309537e+00</item>
# 								</PerDataSpace>
# 							</num_hops>
# 							<energy_per_hop>
# 								<PerDataSpace>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 								</PerDataSpace>
# 							</energy_per_hop>
# 							<energy>
# 								<PerDataSpace>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 								</PerDataSpace>
# 							</energy>
# 							<spatial_reduction_energy>
# 								<PerDataSpace>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 								</PerDataSpace>
# 							</spatial_reduction_energy>
# 						</stats_>
# 					</px>
# 				</second>
# 			</item>
# 			<item>
# 				<first>merge_queue &lt;==&gt; spAL</first>
# 				<second>
# 					<px class_id_reference="23" object_id="_5">
# 						<Network />
# 						<specs_>
# 							<NetworkSpecs>
# 								<name>merge_queue &lt;==&gt; spAL</name>
# 							</NetworkSpecs>
# 							<word_bits>
# 								<t_>16</t_>
# 							</word_bits>
# 							<router_energy />
# 							<wire_energy />
# 							<tile_width>
# 								<t_>3.89124657748102791e+01</t_>
# 							</tile_width>
# 							<energy_per_hop />
# 						</specs_>
# 						<stats_>
# 							<fanout>
# 								<PerDataSpace>
# 									<item>1</item>
# 									<item>1</item>
# 									<item>1</item>
# 								</PerDataSpace>
# 							</fanout>
# 							<distributed_fanout>
# 								<PerDataSpace>
# 									<item>0</item>
# 									<item>0</item>
# 									<item>0</item>
# 								</PerDataSpace>
# 							</distributed_fanout>
# 							<multicast_factor>
# 								<PerDataSpace>
# 									<item>1</item>
# 									<item>1</item>
# 									<item>1</item>
# 								</PerDataSpace>
# 							</multicast_factor>
# 							<ingresses>
# 								<PerDataSpace>
# 									<item>
# 										<count>1</count>
# 										<item_version>0</item_version>
# 										<item>8</item>
# 									</item>
# 									<item>
# 										<count>1</count>
# 										<item_version>0</item_version>
# 										<item>64</item>
# 									</item>
# 									<item>
# 										<count>1</count>
# 										<item_version>0</item_version>
# 										<item>64</item>
# 									</item>
# 								</PerDataSpace>
# 							</ingresses>
# 							<distributed_multicast>
# 								<PerDataSpace>
# 									<item>0</item>
# 									<item>0</item>
# 									<item>0</item>
# 								</PerDataSpace>
# 							</distributed_multicast>
# 							<link_transfers>
# 								<PerDataSpace>
# 									<item>0</item>
# 									<item>0</item>
# 									<item>0</item>
# 								</PerDataSpace>
# 							</link_transfers>
# 							<spatial_reductions>
# 								<PerDataSpace>
# 									<item>0</item>
# 									<item>0</item>
# 									<item>0</item>
# 								</PerDataSpace>
# 							</spatial_reductions>
# 							<link_transfer_energy>
# 								<PerDataSpace>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 								</PerDataSpace>
# 							</link_transfer_energy>
# 							<num_hops>
# 								<PerDataSpace>
# 									<item>5.00000000000000000e-01</item>
# 									<item>5.00000000000000000e-01</item>
# 									<item>5.00000000000000000e-01</item>
# 								</PerDataSpace>
# 							</num_hops>
# 							<energy_per_hop>
# 								<PerDataSpace>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 								</PerDataSpace>
# 							</energy_per_hop>
# 							<energy>
# 								<PerDataSpace>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 								</PerDataSpace>
# 							</energy>
# 							<spatial_reduction_energy>
# 								<PerDataSpace>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 								</PerDataSpace>
# 							</spatial_reduction_energy>
# 						</stats_>
# 					</px>
# 				</second>
# 			</item>
# 			<item>
# 				<first>spAL &lt;==&gt; mac</first>
# 				<second>
# 					<px class_id_reference="23" object_id="_6">
# 						<Network />
# 						<specs_>
# 							<NetworkSpecs>
# 								<name>spAL &lt;==&gt; mac</name>
# 							</NetworkSpecs>
# 							<word_bits>
# 								<t_>16</t_>
# 							</word_bits>
# 							<router_energy />
# 							<wire_energy />
# 							<tile_width>
# 								<t_>3.52065334845678919e+01</t_>
# 							</tile_width>
# 							<energy_per_hop />
# 						</specs_>
# 						<stats_>
# 							<fanout>
# 								<PerDataSpace>
# 									<item>1</item>
# 									<item>1</item>
# 									<item>1</item>
# 								</PerDataSpace>
# 							</fanout>
# 							<distributed_fanout>
# 								<PerDataSpace>
# 									<item>0</item>
# 									<item>0</item>
# 									<item>0</item>
# 								</PerDataSpace>
# 							</distributed_fanout>
# 							<multicast_factor>
# 								<PerDataSpace>
# 									<item>1</item>
# 									<item>1</item>
# 									<item>1</item>
# 								</PerDataSpace>
# 							</multicast_factor>
# 							<ingresses>
# 								<PerDataSpace>
# 									<item>
# 										<count>1</count>
# 										<item_version>0</item_version>
# 										<item>64</item>
# 									</item>
# 									<item>
# 										<count>1</count>
# 										<item_version>0</item_version>
# 										<item>64</item>
# 									</item>
# 									<item>
# 										<count>1</count>
# 										<item_version>0</item_version>
# 										<item>64</item>
# 									</item>
# 								</PerDataSpace>
# 							</ingresses>
# 							<distributed_multicast>
# 								<PerDataSpace>
# 									<item>0</item>
# 									<item>0</item>
# 									<item>0</item>
# 								</PerDataSpace>
# 							</distributed_multicast>
# 							<link_transfers>
# 								<PerDataSpace>
# 									<item>0</item>
# 									<item>0</item>
# 									<item>0</item>
# 								</PerDataSpace>
# 							</link_transfers>
# 							<spatial_reductions>
# 								<PerDataSpace>
# 									<item>0</item>
# 									<item>0</item>
# 									<item>0</item>
# 								</PerDataSpace>
# 							</spatial_reductions>
# 							<link_transfer_energy>
# 								<PerDataSpace>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 								</PerDataSpace>
# 							</link_transfer_energy>
# 							<num_hops>
# 								<PerDataSpace>
# 									<item>5.00000000000000000e-01</item>
# 									<item>5.00000000000000000e-01</item>
# 									<item>5.00000000000000000e-01</item>
# 								</PerDataSpace>
# 							</num_hops>
# 							<energy_per_hop>
# 								<PerDataSpace>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 								</PerDataSpace>
# 							</energy_per_hop>
# 							<energy>
# 								<PerDataSpace>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 								</PerDataSpace>
# 							</energy>
# 							<spatial_reduction_energy>
# 								<PerDataSpace>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 									<item>0.00000000000000000e+00</item>
# 								</PerDataSpace>
# 							</spatial_reduction_energy>
# 						</stats_>
# 					</px>
# 				</second>
# 			</item>
# 		</networks_>
# 	</topology_>
# </engine>
# <mapping class_id="30" tracking_level="0" version="0">
# 	<datatype_bypass_nest>
# 		<item class_id="31" tracking_level="0" version="0">
# 			<bits>0000000000000101</bits>
# 		</item>
# 		<item>
# 			<bits>0000000000000100</bits>
# 		</item>
# 		<item>
# 			<bits>0000000000000110</bits>
# 		</item>
# 	</datatype_bypass_nest>
# </mapping>
# <a class_id="32" tracking_level="1" version="0" object_id="_7">
# 	<workload_ class_id="33" tracking_level="0" version="0">
# 		<bounds_ class_id="34" tracking_level="0" version="0">
# 			<count>3</count>
# 			<item_version>0</item_version>
# 			<item class_id="35" tracking_level="0" version="0">
# 				<first>0</first>
# 				<second>8</second>
# 			</item>
# 			<item>
# 				<first>1</first>
# 				<second>8</second>
# 			</item>
# 			<item>
# 				<first>2</first>
# 				<second>8</second>
# 			</item>
# 		</bounds_>
# 		<coefficients_>
# 			<count>0</count>
# 			<item_version>0</item_version>
# 		</coefficients_>
# 		<densities_ class_id="36" tracking_level="0" version="0">
# 			<count>3</count>
# 			<item_version>0</item_version>
# 			<item class_id="37" tracking_level="0" version="0">
# 				<first>0</first>
# 				<second class_id="38" tracking_level="0" version="1">
# 					<px class_id="39" class_name="problem::FixedStructuredDistribution" tracking_level="1" version="0" object_id="_8">
# 						<DensityDistribution class_id="40" tracking_level="0" version="0" />
# 						<specs_ class_id="41" tracking_level="0" version="0">
# 							<DensityDistributionSpecs class_id="42" tracking_level="0" version="0">
# 								<type>UNSET</type>
# 							</DensityDistributionSpecs>
# 							<type>fixed-structured</type>
# 							<fixed_density>1.00000000000000000e+00</fixed_density>
# 						</specs_>
# 					</px>
# 				</second>
# 			</item>
# 			<item>
# 				<first>1</first>
# 				<second>
# 					<px class_id_reference="39" object_id="_9">
# 						<DensityDistribution />
# 						<specs_>
# 							<DensityDistributionSpecs>
# 								<type>UNSET</type>
# 							</DensityDistributionSpecs>
# 							<type>fixed-structured</type>
# 							<fixed_density>1.00000000000000000e+00</fixed_density>
# 						</specs_>
# 					</px>
# 				</second>
# 			</item>
# 			<item>
# 				<first>2</first>
# 				<second>
# 					<px class_id_reference="39" object_id="_10">
# 						<DensityDistribution />
# 						<specs_>
# 							<DensityDistributionSpecs>
# 								<type>UNSET</type>
# 							</DensityDistributionSpecs>
# 							<type>fixed-structured</type>
# 							<fixed_density>1.00000000000000000e+00</fixed_density>
# 						</specs_>
# 					</px>
# 				</second>
# 			</item>
# 		</densities_>
# 	</workload_>
# </a>
# </boost_serialization>

# %%
from parse_timeloop_output import parse_timeloop_stats

stats = parse_timeloop_stats('./output/timeloop-mapper.map+stats.xml')

stats
# Out:
# {'problem': [512, 512, 512],
#  'utilization': 1.0,
#  'cycles': 524288,
#  'energy_pJ': 1993513349.9803202,
#  'energy_per_mac': 14.852831885071994,
#  'macs': 134217728,
#  'energy_breakdown_pJ': {'MAC': {'energy': 75269301.8624, 'utilization': 1.0},
#   'Buffer': {'energy': 1713568764.3955202,
#    'storage_access_energy': 1713568764.3955202,
#    'read_energy': 1139779483.72992,
#    'temporal_add_energy': 0.0,
#    'spatial_add_energy': 0.0,
#    'address_generation_energy': 0.0,
#    'network_energy': 0.0,
#    'energy_per_access_per_instance': array([4.25016,     nan, 4.25016]),
#    'reads_per_instance': array([524288,      0, 523264]),
#    'updates_per_instance': array([     0,      0, 524288]),
#    'fills_per_instance': array([2048,    0, 1024]),
#    'accesses_per_instance': array([ 526336,       0, 1048576]),
#    'instances': array([256, 256, 256]),
#    'utilization': 0.501953125,
#    'multicast': array([1, 1, 1]),
#    'dist_multicast': array([0, 0, 0]),
#    'num_hops': array([0.5, 0.5, 0.5]),
#    'ingresses': array([524288, 524288, 524288]),
#    'energy_per_hop_per_instance': array([0., 0., 0.])},
#   'BackingStorage': {'energy': 204675283.7224,
#    'storage_access_energy': 204675283.7224,
#    'read_energy': 169237575.1712,
#    'temporal_add_energy': 0.0,
#    'spatial_add_energy': 0.0,
#    'address_generation_energy': 0.0,
#    'network_energy': 0.0,
#    'energy_per_access_per_instance': array([161.39752881, 161.39752881, 135.18412991]),
#    'reads_per_instance': array([524288, 524288,      0]),
#    'updates_per_instance': array([     0,      0, 262144]),
#    'fills_per_instance': array([0, 0, 0]),
#    'accesses_per_instance': array([524288, 524288, 262144]),
#    'instances': array([1, 1, 1]),
#    'utilization': 0.75,
#    'multicast': array([  1, 256,   1]),
#    'dist_multicast': array([0, 0, 0]),
#    'num_hops': array([  8. , 255.5,   8. ]),
#    'ingresses': array([524288, 524288, 262144]),
#    'energy_per_hop_per_instance': array([0., 0., 0.])}}}
